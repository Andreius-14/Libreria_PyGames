# %% [markdown]
# ### Recomendaciones
# ---
# 🌱 Constantes [Recomiendo Hacer un archivo solo con las Constantes]

# %% [markdown]
# # Basico

# %%
import pygame, sys
pygame.init()

# CODIGO

pygame.quit()

# %%
import pygame, sys
pygame.init()

# [Basic] Pantalla - Tamaño Creacion Frame
size = (800, 500)
screen = pygame.display.set_mode(size)
clock = pygame.time.Clock()


pygame.quit()

# %%
import pygame, sys
pygame.init()

# [Basic] Pantalla
size = (800, 500)
screen = pygame.display.set_mode(size)
clock = pygame.time.Clock()

# [Basic] Constantes
BLACK = (0,0,0)
WHITE = (255,255,255)
GREEN = (0,225,0)
RED   = (225,0,0)
BLUE   = (0,0,225)

# [Basic] Variables
game_over = False

# [Basic] Bucle Principal 
# [Basic] Game-Dev [Update]
while not game_over:
    
    # [01] Event's Loop
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
             game_over = True
        
    # [02] Eventos
    # [03] Logica
    # [04] Zona de Dibujo
    screen. fill (WHITE)
    
    # [05] Colisiones
    # [06] Codigo Del Juego   
    # [07] Extra  
    pygame.display.flip()
    clock.tick(60)


pygame.quit()

# %% [markdown]
# # Game - Cierre Bucle

# %%
import pygame, sys
pygame.init()

# [Basic] Constantes
BLACK = (0,0,0)
WHITE = (255,255,255)
GREEN = (0,225,0)
RED   = (225,0,0)
BLUE   = (0,0,225)

# [Basic] Pantalla
size = (800, 500)
screen = pygame.display.set_mode(size)
clock = pygame.time.Clock()

# [Basic] Variables
game_over = False

# [Basic] Bucle Principal 
# [Basic] Game-Dev [Update]
while not game_over:
    
    # [01] Event's Loop
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            game_over = True
            
    # [02] Eventos
    # [03] Logica
    # [04] Zona de Dibujo
    # [05] Colisiones
    # [06] Codigo Del Juego   
    # [07] Extra  
    pygame.display.flip()
    clock.tick(60)

pygame.quit()

# %%
import pygame, sys
pygame.init()

# [Basic] Constantes
BLACK = (0,0,0)
WHITE = (255,255,255)
GREEN = (0,225,0)
RED   = (225,0,0)
BLUE   = (0,0,225)

# [Basic] Pantalla
size = (800, 500)
screen = pygame.display.set_mode(size)
clock = pygame.time.Clock()

# [Basic] Variables

# [Basic] Bucle Principal 
# [Basic] Game-Dev [Update]
while True:
    
    # [01] Event's Loop
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()
            
    # [02] Eventos
    # [03] Logica
    # [04] Zona de Dibujo
    # [05] Colisiones
    # [06] Codigo Del Juego   
    # [07] Extra   
    pygame.display.flip()
    clock.tick(60)

# %% [markdown]
# # Mouse y Teclado

# %%
import pygame, sys
pygame.init()

# [Basic] Constantes

# [Basic] Pantalla
size = (800, 500)
screen = pygame.display.set_mode(size)
clock = pygame.time.Clock()

# [Basic] Variables

# [Basic] Propiedades
pygame.mouse.set_visible(0)  # 🌱 Visibilidad del Mouse

# [Basic] Bucle Principal 
# [Basic] Game-Dev [Update]
while True:
    
    # [01] Event's Loop
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()
            
    # [02] Eventos
    # [03] Logica
    # [04] Zona de Dibujo
    # [05] Colisiones
    # [06] Codigo Del Juego   
    
    print(pygame.mouse.get_pos())   # 🌱 Coordenada de Mouse en La ventana Pygame
    
    # [07] Extra 
    pygame.display.flip()
    clock.tick(60)

# %%
import pygame, sys
pygame.init()

# [Basic] Constantes
BLACK = (0,0,0)
WHITE = (255,255,255)
GREEN = (0,225,0)
RED   = (225,0,0)
BLUE   = (0,0,225)

# [Basic] Pantalla
size = (800, 500)
screen = pygame.display.set_mode(size)
clock = pygame.time.Clock()

# [Basic] Variables
coord_x = 10
coord_y = 10

x_speed = 0
y_speed = 0

# [Basic] Propiedades


# [Basic] Bucle Principal 
# [Basic] Game-Dev [Update]
while True:
    # [01] Event's Loop
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()
            
        # 🌱 Evento-Teclado 🌱
        if event.type == pygame.KEYDOWN:
            if event.key == pygame.K_LEFT:
                x_speed = -3
            if event.key == pygame.K_RIGHT:
                x_speed = 3
            if event.key == pygame.K_UP:
                y_speed = -3
            if event.key == pygame.K_DOWN:
                y_speed = 3

        if event.type == pygame.KEYUP:
            if event.key == pygame.K_LEFT or event.key == pygame.K_RIGHT:
                x_speed = 0
            if event.key == pygame.K_UP or event.key == pygame.K_DOWN:
                y_speed = 0
                
    # [02] Eventos
    # [03] Logica
    # [04] Zona de Dibujo
    screen. fill (WHITE)
    
    # [05] Colisiones
    # [06] Codigo Del Juego  
    coord_x += x_speed
    coord_y += y_speed
    pygame.draw.rect(screen,RED,(coord_x,coord_y,100,100)) 
    
    # [07] Extra 
    pygame.display.flip()
    clock.tick(60)
